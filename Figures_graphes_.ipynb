# %% [markdown]
# # Figures & Axes avec matplotlib
#
# `Réglez l'encodage en` $utf-8$!

# %%
#coding:utf-8
import matplotlib.pyplot as plt #.pyplot est un sous module de matplotlib
import numpy as np #Accéder au vecteurs&matrices etc.....
fig, ax = plt.subplots() 
x = np.linspace(-5,5,200)#modifiez la dernière valeur et voir le résultat...
y = np.sin(x)
ax.plot(x, y) #on peut faire également plt.plot(x, y)
plt.show()

# %%
#coding:utf-8
import matplotlib.pyplot as plt
import numpy as np
fig , ax = plt.subplots()
x = np.linspace(0,5,10)
y = np.cos(x)
ha = "h4cK3rM4n04"
ax.plot(x, y,label = ha)
ax.plot(x**2, y**3, label = ha[::-1])
ax.legend()#label ne fonctionne pas sans cette ligne de commande spécifique
plt.show()
